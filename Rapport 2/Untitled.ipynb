# %%
import numpy as np

acts = [np.random.rand(k+1, 2*k) for k in range(1,5)]
print(acts)
print(len(acts))
print(acts[3])
print(acts[-1])
# Out:
# [array([[0.95503327, 0.07014903],
#        [0.36316918, 0.54851455]]), array([[0.90236912, 0.47661986, 0.72811118, 0.99527867],
#        [0.84520134, 0.78212526, 0.38815845, 0.54910535],
#        [0.31351751, 0.03969714, 0.67909682, 0.72436458]]), array([[0.72942154, 0.3253392 , 0.41615316, 0.3650602 , 0.44319794,
#         0.12662839],
#        [0.13701195, 0.27459861, 0.19565538, 0.40236753, 0.82755717,
#         0.8771571 ],
#        [0.02925133, 0.64095249, 0.86262945, 0.69382654, 0.68828715,
#         0.05050603],
#        [0.05673256, 0.6471771 , 0.76131123, 0.83291448, 0.1305186 ,
#         0.80596854]]), array([[0.37032913, 0.51712093, 0.46336616, 0.68435779, 0.04088988,
#         0.45348024, 0.37695372, 0.27263424],
#        [0.61099601, 0.13829356, 0.39542661, 0.81574451, 0.83014982,
#         0.08188006, 0.74380412, 0.45926458],
#        [0.91681983, 0.98183676, 0.55896417, 0.87260164, 0.58479244,
#         0.52973612, 0.05471583, 0.85790444],
# ...
